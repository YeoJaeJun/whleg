# %% [markdown]
# # 2. Object Detection Outline

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# 사전 학습된 YOLOv8 모델 로드 (yolov8n = 가장 가벼운 모델)
model = YOLO('yolov8n.pt')

# %%
# 이미지 로드
image_path = 'image2.jpg'
img = cv2.imread(image_path)

# 추론 수행
results = model(img)

# 시각화 (YOLO 내장 메서드 활용)
results[0].show()
# Out:
# 0: 352x640 9 persons, 2 cars, 1 bus, 2 handbags, 47.6ms
# Speed: 2.2ms preprocess, 47.6ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)

# %%
import numpy as np

# YOLOv8 추론
results = model(img)
result = results[0]

# 바운딩 박스 시각화
for box in result.boxes:
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    cls = int(box.cls[0])
    label = model.names[cls]
    conf = float(box.conf[0])
    cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
    cv2.putText(img, f'{label} {conf:.2f}', (x1, y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

# RGB로 변환 후 matplotlib 시각화
plt.figure(figsize=(10, 6))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title("YOLOv8 Detection Result")
plt.show()
# Out:
# 0: 352x640 9 persons, 2 cars, 1 bus, 2 handbags, 47.8ms
# Speed: 2.0ms preprocess, 47.8ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
